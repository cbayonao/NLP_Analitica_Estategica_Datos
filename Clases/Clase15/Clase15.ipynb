# %% [markdown]
# # Bienvenidos, comenzamos a las 7:30 a.m.

# %% [markdown]
# <center><img src='img/fake.png' style='height:300px; float: center; margin: 0px 15px 15px 0px'></center>
#
# - NYT: [1](https://www.nytimes.com/interactive/2020/11/21/science/artificial-intelligence-fake-people-faces.html?campaign_id=9&emc=edit_nn_20201122&instance_id=24364&nl=the-morning&regi_id=139532851&segment_id=45168&te=1&user_id=8ee0b46bb64f8248ed9cdc30e43c182e)
#
# - 🎄🎅 Advent of Code https://adventofcode.com/ [(Ejemplo)](https://github.com/vivianamarquez/Advent-of-Code-2018/blob/master/Day%201/Day%201.ipynb)

# %% [markdown]
# <center><img src='img/students.jpg' style='height:400px; float: center; margin: 0px 15px 15px 0px'></center>
#
# ### Estudios de Caso
# #### NLP - Analítica Estratégica de Datos
# <br><b>Fundación Universitaria Konrad Lorenz</b>
# <br>Docente: Viviana Márquez [vivianam.penama@konradlorenz.edu.co](mailto:vivianama.penam@konradlorenz.edu.co)
# <br>Clase #15: Noviembre 28, 2020

# %% [markdown]
# # Retroalimentación taller 11

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
SIA = SentimentIntensityAnalyzer()
SIA.lexicon
#'foo' in SIA.lexicon.keys()

new_words = {
    'foo': 2.0,
}

SIA.lexicon.update(new_words)
'foo' in SIA.lexicon.keys()
# Out:
# True

# %% [markdown]
# # Notas

# %% [markdown]
# # 🥁 Quién será el primero [*](https://www.youtube.com/watch?v=KGe_wKzahgA&ab_channel=McTylaa)

# %%
import pandas as pd

df = pd.read_csv('e.csv')
df.head()
# Out:
#                   Nombre
# 0               Duberney
# 1  Fabian & Alejandro F.
# 2    Norma & Jhon Freddy
# 3               Nicaulis
# 4        Diego & Vanessa

# %%
import random
numeros = list(range(0,25))

# %%
def los_elegidos():
    num = random.choice(numeros)
    print("Los elegidos son...")
    print(df.Nombre.loc[num])
    numeros.remove(num)
    
los_elegidos()
# Out:
# Los elegidos son...
# Ricardo

# %%
df.reset_index(inplace=True)
df['pasó'] = df['index'].apply(lambda val: False if val in numeros else True)
df.to_csv("e2.csv")

# %% [markdown]
# <center><img src='img/fin.gif'>
#
# ### Próximas clases: Proyectos Finales
