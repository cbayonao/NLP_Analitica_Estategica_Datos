# %% [markdown]
# # Bienvenidos, comenzamos a las 7:30 a.m.

# %% [markdown]
# ### -  ¿Cuál es la palabra del año? [1](https://www.nytimes.com/2020/11/22/arts/oxford-word-of-the-year-coronavirus.html?campaign_id=9&emc=edit_nn_20201123&instance_id=24380&nl=the-morning&regi_id=139532851&segment_id=45216&te=1&user_id=8ee0b46bb64f8248ed9cdc30e43c182e)
#
# ### - GPT-3 [2](https://www.nytimes.com/2020/11/24/science/artificial-intelligence-ai-gpt3.html?campaign_id=9&emc=edit_nn_20201124&instance_id=24415&nl=the-morning&regi_id=139532851&segment_id=45301&te=1&user_id=8ee0b46bb64f8248ed9cdc30e43c182e)

# %% [markdown]
# <center><img src='img/students.jpg' style='height:400px; float: center; margin: 0px 15px 15px 0px'></center>
#
# ### Estudios de Caso
# #### NLP - Analítica Estratégica de Datos
# <br><b>Fundación Universitaria Konrad Lorenz</b>
# <br>Docente: Viviana Márquez [vivianam.penama@konradlorenz.edu.co](mailto:vivianama.penam@konradlorenz.edu.co)
# <br>Clase #16: Diciembre 5, 2020

# %% [markdown]
# # 🥁 Quién será el primero [*](https://www.youtube.com/watch?v=KGe_wKzahgA&ab_channel=McTylaa)

# %%
import pandas as pd

df = pd.read_csv('e2.csv')
df = df[~df.pasó]
df = df[['Nombre']].reset_index(drop=True)
df.head()
# Out:
#                 Nombre
# 0             Duberney
# 1  Norma & Jhon Freddy
# 2                Xiomy
# 3        Jonathan Fuya
# 4    Jhonathan Giraldo

# %%
import random
numeros = list(range(0,14))

# %%
def los_elegidos():
    num = random.choice(numeros)
    print("Los elegidos son...")
    print(df.Nombre.loc[num])
    numeros.remove(num)
    
los_elegidos()
# Out:
# Los elegidos son...
# Norma & Jhon Freddy

# %% [markdown]
# <center><img src='img/fin.gif'>
#
# Gracias mis estudiantes ❤️
